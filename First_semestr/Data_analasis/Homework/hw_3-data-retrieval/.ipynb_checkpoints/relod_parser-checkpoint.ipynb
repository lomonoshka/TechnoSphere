# %%
import requests
from bs4 import BeautifulSoup
import json
from lxml import etree, html as lhtml

# %%
relod_url = 'https://shop.relod.ru'

# %%
fiction_url = f'{relod_url}catalog-products/4577/?num=20&sort=PROPERTY_RATING&order=desc'

# %%
data = {"siteId": "s1",
    "template": "bxready.73c1485ff4ce40486bbd30b6d9f2f4df8fafe937859e42fbb8f388a4a0518226",
    "parameters": "....00631674e61b33c8e8aa3994ce36c904c9993f986d212be47e77fd4ca26223d4",
    "action": "showMore",
    "PAGEN_1": "1"}

# %%
links = set()
number_of_pages = 2
for i in range(1, number_of_pages + 1):
    data["PAGEN_1"] = str(i)
    r = requests.post('https://shop.relod.ru/bitrix/components/bxready.market2/catalog.section/ajax.php',
                  data=data)
    fiction_soup = BeautifulSoup(r.content, 'lxml')
    table = fiction_soup.find('div', {'data-entity': 'container-1'})
    div_tags = table.find_all('div', {'class': 'bxr-element-name'})
    links |= {div_tag.find('a')['href'] for div_tag in div_tags}

# %%
links = list(links)

# %%
test_html = get_page_html('https://shop.relod.ru/catalog-products/would_you_believe_marzipan_contains_cyanide')

# %%
'abcsd'.find('bcs')
# Out:
# 1

# %%
re.search(r'var ptvSettings = {([./s]?)}', "var ptvSettings = {s}")
# Out:
# <re.Match object; span=(0, 21), match='var ptvSettings = {s}'>

# %%
re.search(r'var ptvSettings = {((/s.)?)}', str(test_html))

# %%
test_html
# Out:
# <!DOCTYPE html>
# <html itemscope="" itemtype="http://schema.org/WebPage" lang="ru" xml:lang="ru">
# <head>
# <!-- Google Tag Manager -->
# <script data-skip-moving="true">(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#                 new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#             j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#             'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#         })(window,document,'script','dataLayer','GTM-T3HTQQ9');</script>
# <!-- End Google Tag Manager -->
# <!-- Facebook Pixel Code --><script data-skip-moving="true">!function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window, document,'script','https://connect.facebook.net/en_US/fbevents.js');fbq('init', '1214939012022686');fbq('track', 'PageView');</script><noscript><img height="1" src="https://www.facebook.com/tr?id=1214939012022686&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript><!-- End Facebook Pixel Code -->
# <title>Eleanor Oliphant is Completely Fine: Debut Bestseller and Costa First Novel Book Award winner 2017 купить недорого в интернет-магазине - RELOD | ISBN 9780008172145</title>
# <link href="https://shop.relod.ru/catalog-products/eleanor_oliphant_is_completely_fine_debut_bestseller_and_costa_first_novel_book_award_winner_2017/" rel="canonical"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.2" name="viewport"/>
# <meta content="ЗАО РЕЛОД" property="og:title"/>
# <meta content="" property="og:description"/>
# <meta content="shop.relod.ru/upload/alexkova.market2/983/98344d181a3aac8e9730b2aede121d1e.png" property="og:image"/>
# <meta content="website" property="og:type"/>
# <meta content="shop.relod.ru" property="og:url"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="eleanor oliphant is completely fine: debut bestseller and costa first novel book award winner 2017" name="keywords"/>
# <meta content="Eleanor Oliphant is Completely Fine: Debut Bestseller and Costa First Novel Book Award winner 2017: цена, отзывы, описание. Купить книги с доставкой по Москве и всей России  | ISBN 9780008172145" name="description"/>
# <script data-skip-moving="true" type="text/javascript">(function(w, d) {var v = w.frameCacheVars = {'CACHE_MODE':'HTMLCACHE','storageBlocks':[],'dynamicBlocks':{'region_controller':'d41d8cd98f00','k7Xxik':'d41d8cd98f00','mobile_menu':'6c0967ce0a6d','bxr_login_frame':'d41d8cd98f00','bxr_small_basket':'0d160d1730b4','qepX1R':'4d808210f0f1','prices_detail':'002a6f0b3d87','recommended_custom':'d41d8cd98f00','buyPA2':'d41d8cd98f00','sender-subscribe':'02dd65dd0ca8','iblock_fast_fiew':'b91115d80a47','one_click_order':'d41d8cd98f00'},'AUTO_UPDATE':true,'AUTO_UPDATE_TTL':'0'};var inv = false;if (v.AUTO_UPDATE === false){if (v.AUTO_UPDATE_TTL && v.AUTO_UPDATE_TTL > 0){var lm = Date.parse(d.lastModified);if (!isNaN(lm)){var td = new Date().getTime();if ((lm + v.AUTO_UPDATE_TTL * 1000) >= td){w.frameRequestStart = false;w.preventAutoUpdate = true;return;}inv = true;}}else{w.frameRequestStart = false;w.preventAutoUpdate = true;return;}}var r = w.XMLHttpRequest ? new XMLHttpRequest() : (w.ActiveXObject ? new w.ActiveXObject("Microsoft.XMLHTTP") : null);if (!r) { return; }w.frameRequestStart = true;var m = v.CACHE_MODE; var l = w.location; var x = new Date().getTime();var q = "?bxrand=" + x + (l.search.length > 0 ? "&" + l.search.substring(1) : "");var u = l.protocol + "//" + l.host + l.pathname + q;r.open("GET", u, true);r.setRequestHeader("BX-ACTION-TYPE", "get_dynamic");r.setRequestHeader("X-Bitrix-Composite", "get_dynamic");r.setRequestHeader("BX-CACHE-MODE", m);r.setRequestHeader("BX-CACHE-BLOCKS", v.dynamicBlocks ? JSON.stringify(v.dynamicBlocks) : "");if (inv){r.setRequestHeader("BX-INVALIDATE-CACHE", "Y");}try { r.setRequestHeader("BX-REF", d.referrer || "");} catch(e) {}if (m === "APPCACHE"){r.setRequestHeader("BX-APPCACHE-PARAMS", JSON.stringify(v.PARAMS));r.setRequestHeader("BX-APPCACHE-URL", v.PAGE_URL ? v.PAGE_URL : "");}r.onreadystatechange = function() {if (r.readyState != 4) { return; }var a = r.getResponseHeader("BX-RAND");var b = w.BX && w.BX.frameCache ? w.BX.frameCache : false;if (a != x || !((r.status >= 200 && r.status < 300) || r.status === 304 || r.status === 1223 || r.status === 0)){var f = {error:true, reason:a!=x?"bad_rand":"bad_status", url:u, xhr:r, status:r.status};if (w.BX && w.BX.ready){BX.ready(function() {setTimeout(function(){BX.onCustomEvent("onFrameDataRequestFail", [f]);}, 0);});}else{w.frameRequestFail = f;}return;}if (b){b.onFrameDataReceived(r.responseText);if (!w.frameUpdateInvoked){b.update(false);}w.frameUpdateInvoked = true;}else{w.frameDataString = r.responseText;}};r.send();})(window, document);</script>
# <script data-skip-moving="true" type="text/javascript">(function(w, d, n) {var cl = "bx-core";var ht = d.documentElement;var htc = ht ? ht.className : undefined;if (htc === undefined || htc.indexOf(cl) !== -1){return;}var ua = n.userAgent;if (/(iPad;)|(iPhone;)/i.test(ua)){cl += " bx-ios";}else if (/Android/i.test(ua)){cl += " bx-android";}cl += (/(ipad|iphone|android|mobile|touch)/i.test(ua) ? " bx-touch" : " bx-no-touch");cl += w.devicePixelRatio && w.devicePixelRatio >= 2? " bx-retina": " bx-no-retina";var ieVersion = -1;if (/AppleWebKit/.test(ua)){cl += " bx-chrome";}else if ((ieVersion = getIeVersion()) > 0){cl += " bx-ie bx-ie" + ieVersion;if (ieVersion > 7 && ieVersion < 10 && !isDoctype()){cl += " bx-quirks";}}else if (/Opera/.test(ua)){cl += " bx-opera";}else if (/Gecko/.test(ua)){cl += " bx-firefox";}if (/Macintosh/i.test(ua)){cl += " bx-mac";}ht.className = htc ? htc + " " + cl : cl;function isDoctype(){if (d.compatMode){return d.compatMode == "CSS1Compat";}return d.documentElement && d.documentElement.clientHeight;}function getIeVersion(){if (/Opera/i.test(ua) || /Webkit/i.test(ua) || /Firefox/i.test(ua) || /Chrome/i.test(ua)){return -1;}var rv = -1;if (!!(w.MSStream) && !(w.ActiveXObject) && ("ActiveXObject" in w)){rv = 11;}else if (!!d.documentMode && d.documentMode >= 10){rv = 10;}else if (!!d.documentMode && d.documentMode >= 9){rv = 9;}else if (d.attachEvent && !/Opera/.test(ua)){rv = 8;}if (rv == -1 || rv == 8){var re;if (n.appName == "Microsoft Internet Explorer"){re = new RegExp("MSIE ([0-9]+[\.0-9]*)");if (re.exec(ua) != null){rv = parseFloat(RegExp.$1);}}else if (n.appName == "Netscape"){rv = 11;re = new RegExp("Trident/.*rv:([0-9]+[\.0-9]*)");if (re.exec(ua) != null){rv = parseFloat(RegExp.$1);}}}return rv;}})(window, document, navigator);</script>
# <link href="//opt-1458870.ssl.1c-bitrix-cdn.ru/bitrix/cache/css/s1/market2_v1/kernel_main/kernel_main_v1.css?160563984032843" rel="stylesheet" type="text/css"/>
# <link href="//opt-1458870.ssl.1c-bitrix-cdn.ru/bitrix/css/main/bootstrap.css?1562137947121326" rel="stylesheet" type="text/css"/>
# <link href="//opt-1458870.ssl.1c-bitrix-cdn.ru/bitrix/css/main/font-awesome.css?152343936928777" rel="stylesheet" type="text/css"/>
# <link href="//opt-1458870.ssl.1c-bitrix-cdn.ru/bitrix/js/ui/fonts/opensans/ui.font.opensans.css?15607765212003" rel="stylesheet" type="text/css"/>
# <link href="//opt-1458870.ssl.1c-bitrix-cdn.ru/bitrix/js/alexkova.bxready2/slick/slick.css?15234393691963" rel="stylesheet" type="text/css"/>
# <link href="//opt-1458870.ssl.1c-bitrix-cdn.ru/bitrix/js/alexkova.bxready2/countdown/countdown.css?15234393691512" rel="stylesheet" type="text/css"/>
# <link href="//opt-1458870.ssl.1c-bitrix-cdn.ru/bitrix/cache/css/s1/market2_v1/page_4207af916d1983899893d38e2b324cc6/page_4207af916d1983899893d38e2b324cc6_v1.css?160563960558990" rel="stylesheet" type="text/css"/>
# <link href="//opt-1458870.ssl.1c-bitrix-cdn.ru/bitrix/cache/css/s1/market2_v1/default_82f2059a4351614a56bad981f2ba8ca3/default_82f2059a4351614a56bad981f2ba8ca3_v1.css?160563960513629" rel="stylesheet" type="text/css"/>
# <link href="//opt-1458870.ssl.1c-bitrix-cdn.ru/bitrix/cache/css/s1/market2_v1/default_ca3818488307773c4efc80d5082d1ac7/default_ca3818488307773c4efc80d5082d1ac7_v1.css?16056396051709" rel="stylesheet" type="text/css"/>
# <link href="//opt-1458870.ssl.1c-bitrix-cdn.ru/bitrix/cache/css/s1/market2_v1/default_b656b6ac7b87524c5308226c13c3c743/default_b656b6ac7b87524c5308226c13c3c743_v1.css?160563960516676" rel="stylesheet" type="text/css"/>
# <link href="//opt-1458870.ssl.1c-bitrix-cdn.ru/bitrix/cache/css/s1/market2_v1/default_bce1e0c429095aa209797cb02c3f5a17/default_bce1e0c429095aa209797cb02c3f5a17_v1.css?160563960531046" rel="stylesheet" type="text/css"/>
# <link href="//opt-1458870.ssl.1c-bitrix-cdn.ru/bitrix/cache/css/s1/market2_v1/default_217d40aba8315cd87d1d1e3a96a252f1/default_217d40aba8315cd87d1d1e3a96a252f1_v1.css?160563960532864" rel="stylesheet" type="text/css"/>
# <link data-template-style="true" href="//opt-1458870.ssl.1c-bitrix-cdn.ru/bitrix/cache/css/s1/market2_v1/template_8c19890d0028955094f7f4f233140e6c/template_8c19890d0028955094f7f4f233140e6c_v1.css?1605639605156552" rel="stylesheet" type="text/css"/>
# <style>img[src*="captcha.php"] {cursor: pointer;}</style>
# </head>
# <body class="">
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-T3HTQQ9" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <div id="panel"></div>
# <div itemscope="" itemtype="http://schema.org/Organization" style="visibility:hidden;">
# <meta content="ЗАО РЕЛОД" itemprop="name"/>
# <meta content="shop.relod.ru/upload/alexkova.market2/983/98344d181a3aac8e9730b2aede121d1e.png" itemprop="logo"/>
# <meta content="" itemprop="telephone"/>
# <meta content="" itemprop="faxNumber"/>
# <meta content="online@relod.ru" itemprop="email"/>
# <meta content="" itemprop="description"/>
# <div itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress" style="visibility:hidden;">
# <meta content="Пушкарев переулок, д.17" itemprop="streetAddress"/>
# <meta content="107045" itemprop="postalCode"/>
# <meta content="Москва" itemprop="addressLocality"/>
# </div>
# <meta content="https://shop.relod.ru" itemprop="url"/>
# </div>
# <div class="bxr-full-width">
# <div class="container bxr-bg-container xl" onclick="try{yaCounter30426462.reachGoal('click_banner');gtag('event', 'Клик по баннеру в шапке',{'event_category': 'banner','event_action': 'click'});}catch(e){console.log('error while triggering GA or YM targets');console.log(e);} return true;">
# <div class="row"><div class="col-xs-12">
# <div id="bxdynamic_k7Xxik_start" style="display:none"></div><div id="bxdynamic_k7Xxik_end" style="display:none"></div> </div>
# </div></div>
# </div>
# <header class="bxr-full-width">
# <div id="bxdynamic_mobile_menu_start" style="display:none"></div> <div class="hidden-md hidden-lg container bxr-bg-container xl">
# <div class="row bxr-b20">
# <div class="col-xs-12">
# <div>
# <nav class="bxr-mobile-push-menu-v2" data-hoverclass="bxr-color">
# <div class="bxr-mobile-push-menu-top pull-right">
# <ul class="bxr-mobile-push-menu-button">
# <li class="bxr-bg-hover-flat bxr-mobile-menu-button-user" data-target="user">
# <a href="/personal/profile/">
# <i class="fa fa-user fa-fw"></i>
# </a>
# </li>
# <li class="bxr-bg-hover-flat bxr-mobile-menu-button-phone" data-target="phone"><i class="fa fa-phone fa-fw"></i></li>
# <li class="bxr-bg-hover-flat bxr-mobile-menu-button-order-history" data-popup-src="#current_statuses_list_popup" onclick="try{yaCounter30426462.reachGoal('track_order');gtag('event', 'Клик по иконке Отследить заказ в шапке',{'event_category': 'track_order','event_action': 'click'});}catch(e){console.log('error while triggering GA or YM targets');console.log(e);}; return true;">
# <svg height="20px" style="transform: translateY(10%);" width="20px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <path d="M19.895,15.814 L10.698,19.984 C10.674,19.995 10.649,20.000 10.623,20.000 C10.589,20.000 10.555,19.990 10.526,19.972 C10.475,19.939 10.443,19.882 10.443,19.821 L10.443,9.175 C10.443,9.105 10.484,9.041 10.548,9.012 L19.745,4.842 C19.801,4.817 19.866,4.822 19.917,4.854 C19.969,4.887 20.000,4.944 20.000,5.005 L20.000,15.651 C20.000,15.721 19.959,15.785 19.895,15.814 ZM10.075,8.260 C10.051,8.271 10.025,8.276 10.000,8.276 C9.974,8.276 9.949,8.271 9.925,8.260 L6.792,6.775 L15.726,2.542 C15.773,2.519 15.828,2.518 15.877,2.540 L18.971,3.901 C19.036,3.929 19.077,3.992 19.078,4.063 C19.078,4.133 19.037,4.197 18.973,4.226 L10.075,8.260 ZM2.904,5.077 L1.028,4.226 C0.963,4.197 0.922,4.133 0.923,4.063 C0.923,3.992 0.965,3.929 1.029,3.901 L9.927,-0.013 C9.973,-0.034 10.026,-0.034 10.073,-0.013 L11.608,0.662 C11.672,0.690 11.714,0.752 11.715,0.822 C11.716,0.892 11.676,0.956 11.613,0.986 L2.904,5.077 ZM2.312,10.490 C2.312,10.539 2.341,10.584 2.386,10.605 L5.927,12.269 C5.944,12.278 5.963,12.282 5.982,12.282 C6.006,12.282 6.030,12.275 6.051,12.262 C6.088,12.239 6.111,12.198 6.111,12.154 L6.111,7.482 L9.452,9.012 C9.516,9.041 9.557,9.105 9.557,9.175 L9.557,19.821 C9.557,19.882 9.526,19.939 9.474,19.972 C9.445,19.990 9.411,20.000 9.377,20.000 C9.352,20.000 9.326,19.994 9.302,19.984 L0.105,15.813 C0.041,15.784 -0.000,15.721 -0.000,15.651 L-0.000,5.005 C-0.000,4.944 0.031,4.887 0.083,4.854 C0.134,4.822 0.199,4.817 0.255,4.842 L2.312,5.786 L2.312,10.490 Z" fill="rgb(97, 97, 97)" fill-rule="evenodd"></path>
# </svg>
# </li>
# <li class="bxr-bg-hover-flat bxr-mobile-menu-button-basket" data-target="basket" onclick="try{yaCounter30426462.reachGoal('click_basket');gtag('event', 'Клик по иконке Моя корзина в шапке',{'event_category': 'click_basket','event_action': 'click'});}catch(e){console.log('error while triggering GA or YM targets');console.log(e);}; return true;">
# <a href="/personal/basket/">
# <i class="fa fa-shopping-basket fa-fw"></i>
# </a>
# </li>
# </ul>
# </div>
# <div class="bxr-mobile-push-menu-bottom">
# <ul class="bxr-mobile-push-menu-button">
# <li class="bxr-bg-hover-flat bxr-mobile-menu-button-menu" data-show="N" data-target="menu"><i class="fa fa-bars fa-fw"></i><span>Меню</span></li>
# <li class="bxr-bg-hover-flat bxr-mobile-menu-button-search" data-target="search"><i class="fa fa-search fa-fw"></i>
# <span>Поиск</span>
# </li>
# </ul>
# </div>
# </nav>
# <div class="clearfix"></div>
# <nav class="bxr-mobile-push-menu">
# <div class="bxr-mobile-push-menu-content">
# <div id="bxr-mobile-menu-body">
# <ul data-child="0" id="bxr-multilevel-menu">
# <li class="title bxr-color">
#                                 Меню                                <span class="menu-arrow-top bxr-border-color"></span>
# </li>
# <li>
# <a class="root-item" href="/info/catalog_mob">
#                                             Каталог                                                                                    </a>
# </li>
# <li>
# <a class="root-item" href="/publisher/">
#                                             Издательства                                                                                    </a>
# </li>
# <li>
# <a class="root-item" href="/author/">
#                                             Авторы                                                                                    </a>
# </li>
# <li>
# <a class="root-item" href="/series/">
#                                             Серии                                                                                    </a>
# </li>
# <li>
# <a class="root-item" href="https://shop.relod.ru/upload/pub/Catalog_OUP_RELOD_v2.pdf">
#                                             Каталог OUP (ELT) и RELOD                                                                                    </a>
# </li>
# <li>
# <a class="root-item" href="/info/how-to-main/">
#                                             Как найти и заказать товар                                                                                    </a>
# </li>
# <li>
# <a class="root-item" href="/news/">
#                                             Новости                                                                                    </a>
# </li>
# <li>
# <a class="root-item" href="/articles/">
#                                             Обзоры                                                                                    </a>
# </li>
# <li>
# <a class="root-item" href="/info/how-to-delivery/">
#                                             Доставка, оплата и сроки                                                                                    </a>
# </li>
# <li class="parent" data-child="9" data-parent="9">
#                                         О нас                                                                                <span class="direction fa fa-chevron-right"></span>
# </li>
# <li class="content-child" data-child="9" data-parent="9"><ul>
# <li class="child bxr-color bxr-color-light-hover" data-parent="9">
#                                                 Назад <span class="direction fa fa-chevron-left"></span>
# </li>
# <li class="child-title">
# <a class="bxr-color-dark" href="/info/o-magazine/">
#                                                 О нас                                                                                            </a>
# <span class="menu-arrow-top bxr-border-color-dark"></span>
# </li>
# <li>
# <a class="root-item" href="/info/o-magazine/contacts/">
#                                             Контакты                                                                                    </a>
# </li>
# <li>
# <a class="root-item" href="/info/o-magazine/reviews/index.php">
#                                             Отзывы о нас                                                                                    </a>
# </li>
# <li>
# <a class="root-item" href="/info/o-magazine/requisites/">
#                                             Реквизиты                                                                                    </a>
# </li>
# <li>
# <a class="root-item" href="/info/o-magazine/pologenie_o_person_dannih/">
#                                             Обработка персональных данных                                                                                    </a>
# </li>
# <li>
# <a class="root-item" href="/info/o-magazine/user_agreement/">
#                                             Условия продажи товаров                                                                                    </a>
# </li>
# <li>
# <a class="root-item" href="/info/o-magazine/user_agreement2/">
#                                             Условия продажи услуг                                                                                    </a>
# </li>
# <li>
# <a class="root-item" href="/info/o-magazine/user_agreement3/">
#                                             Условия продажи цифровых товаров                                                                                    </a>
# </li>
# <li>
# <a class="root-item" href="/info/o-magazine/change-and-return/">
#                                             Возврат товара и денежных средств                                                                                    </a>
# </li>
# </ul></li>
# <li>
# <a class="root-item" href="/actions/">
#                                             Акции                                                                                    </a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# <div class="clearfix"></div>
# <div class="hidden-md hidden-lg">
# <div class="col-xs-12">
# <div class="bxr-mobile-slide row" id="bxr-mobile-search">
# <div class="col-xs-12 bxr-p20">
# <div class="bx-searchtitle" id="title-search-in-top">
# <form action="/product/">
# <div class="bx-input-group">
# <input autocomplete="off" class="bx-form-control" id="title-search-input-in-top" name="q" placeholder="Поиск по сайту" type="text" value=""/>
# <span class="bxr-input-group-btn">
# <button class="btn bxr-btn-default fa fa-search" name="s" type="submit"></button>
# </span>
# </div>
# </form>
# </div>
# </div>
# </div>
# <div class="bxr-mobile-slide row" id="bxr-mobile-phone">
# <div class="col-xs-12 bxr-p20">
# <div class="bxr-mobile-contact-form bxr-b20">
# <table class="bxr-w100">
# <tbody>
# <tr>
# <td>
# <b>Телефон интернет-магазина</b>
# </td>
# <td class="text-right">
# 			 +7(495) 783-94-10
# 		</td>
# </tr>
# <tr>
# <td>
# 			 Время работы оператора (Пн. Вт. Ср.)
# 		</td>
# <td class="text-right">
# 			  09:30 - 21:30
# 		</td>
# </tr>
# <tr>
# <td>
# 			 Время работы оператора (Чт. Пт. Сб. Вс)
# 		</td>
# <td class="text-right">
# 			 09:30 - 17:30
# 		</td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="bxr-mobile-contact-form bxr-built-in-form">
# </div>
# <br/> </div>
# </div>
# </div>
# </div>
# <div class="clearfix"></div>
# </div> </div>
# </div>
# </div>
# <div id="bxdynamic_mobile_menu_end" style="display:none"></div> <div class="container bxr-bg-container xl">
# <div class="row bxr-b20">
# <div class="col-xs-12">
# <div class="bxr-header-panel bxr-header-panel-v1">
# <div class="bxr-top-panel-header-container">
# <div class="bxr-border-color">
# <div class="bxr-upper-part bxr-cloud-all bxr-cloud-all-br3-not bxr-cloud-all-br4-not">
# <div class="row">
# <div class="col-xs-5">
# <ul class="bxr-topline-menu">
# <li class="">
# <a class="selected bxr-font-color-hover bxr-font-color" href="/">Главная</a>
# </li>
# <li class="">
# <a class="bxr-font-color-hover bxr-font-color" href="/info/how-to-main/">Как найти и заказать товар</a>
# </li>
# <li class="">
# <a class="bxr-font-color-hover bxr-font-color" href="/info/how-to-delivery/">Доставка и оплата</a>
# </li>
# <li class="">
# <a class="bxr-font-color-hover bxr-font-color" href="/upload/pub/Catalog_OUP_RELOD_v2.pdf">Каталог OUP(ELT) и RELOD</a>
# </li>
# </ul>
# <div class="clearfix"></div>
# </div>
# <div class="col-xs-7 text-right">
# <div id="top-panel-region-link">
# </div>
# <div id="top-panel-phone-link">
# </div>
# <div class="inline-block bxr-login-container">
# <div id="bxdynamic_bxr_login_frame_start" style="display:none"></div><div id="bxdynamic_bxr_login_frame_end" style="display:none"></div> </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="bxr-lower-part container-fluid bxr-cloud-all bxr-cloud-all-br1-not bxr-cloud-all-br2-not bxr-cloud-all-br4-not bxr-cloud-all-br3-not">
# <div class="row">
# <div class="col-xl-2 col-xml-2 col-xmll-2 bxr-show-left-menu-conteiner col-md-3 col-sm-4 col-xs-12 bxr-element-row-middle">
# <div class="bxr-logo-top-panel bxr-element-col-middle">
# <a href="/">
# <p style="text-align: center;">
# <img alt="RELOD" src="//opt-1458870.ssl.1c-bitrix-cdn.ru/images/logo_relod.png?15256844136039" title="RELOD"/>
# </p>
# </a> </div>
# </div>
# <div class="col-xl-6 col-xml-4 col-xmll-4 col-lg-3 col-xs-6 bxr-element-row-middle hidden-sm hidden-xs">
# <div class="bxr-element-col-middle" id="search_title_container"><div>
# <div class="bx-searchtitle" id="title-search-in-top2">
# <form action="/product/">
# <div class="bx-input-group">
# <input autocomplete="off" class="bx-form-control" id="title-search-input-in-top2" name="q" placeholder="Поиск по сайту" type="text" value=""/>
# <span class="bxr-input-group-btn">
# <button class="btn bxr-btn-default fa fa-search" name="s" type="submit"></button>
# </span>
# </div>
# </form>
# </div>
# </div></div>
# </div>
# <div class="col-xl-2 col-xml-3 col-xmll-3 visible-xl-table hidden-md col-md-3 col-xs-8 hidden-xs bxr-element-row-middle">
# <div class="bxr-element-col-middle text-right bxr-phone-container text-right">
# <ul class="bxr-phone-block phone-big">
# <li>
# <div>
# <a href="tel:+74957839410"><i class="fa fa-phone bxr-bg-hover-light-flat"></i>+7 (495) <b>783-94-10</b><i class="fa fa-angle-down"></i></a>
# </div>
# <ul>
# <div>
# <li><br/>
# <i class="fa fa-clock-o"></i>Время работы оператора 10:30-21:00<br/>
# <small class="text-muted">Ежедневно, кроме праздничных дней </small></li>
# </div>
# <div>
# <li> <a href="mailto:online@relod.ru">Email: online@relod.ru</a></li>
# </div>
# </ul> </li>
# </ul>
# </div>
# </div>
# <div class="col-xl-2 col-xml-3 col-xmll-3 col-sm-3 col-xs-4 bxr-element-row-middle hidden-sm hidden-xs">
# <div class="bxr-element-col-middle bxr-basket-container" id="basket_container"><div>
# <div class="bxr-rpbtn-container">
# <a class="login-line bxr-frame-btn" href="#">
# <i class="fa fa-user-o"></i>
# </a>
# </div>
# <!--noindex-->
# <!--/noindex-->
# <div id="bxdynamic_bxr_small_basket_start" style="display:none"></div> <div class="">
# <div class="basket-body-table-row bxr-basket-row-top" id="bxr-basket-row">
# <div>
# <a class="bxr-mobile-menu-button-order-history bxr-basket-indicator bxr-font-hover-light" data-popup-src="#current_statuses_list_popup" href="javascript:void(0);" title="Отследить заказ">
# <svg height="20px" style="transform:translateY(30%);" width="20px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <path d="M19.895,15.814 L10.698,19.984 C10.674,19.995 10.649,20.000 10.623,20.000 C10.589,20.000 10.555,19.990 10.526,19.972 C10.475,19.939 10.443,19.882 10.443,19.821 L10.443,9.175 C10.443,9.105 10.484,9.041 10.548,9.012 L19.745,4.842 C19.801,4.817 19.866,4.822 19.917,4.854 C19.969,4.887 20.000,4.944 20.000,5.005 L20.000,15.651 C20.000,15.721 19.959,15.785 19.895,15.814 ZM10.075,8.260 C10.051,8.271 10.025,8.276 10.000,8.276 C9.974,8.276 9.949,8.271 9.925,8.260 L6.792,6.775 L15.726,2.542 C15.773,2.519 15.828,2.518 15.877,2.540 L18.971,3.901 C19.036,3.929 19.077,3.992 19.078,4.063 C19.078,4.133 19.037,4.197 18.973,4.226 L10.075,8.260 ZM2.904,5.077 L1.028,4.226 C0.963,4.197 0.922,4.133 0.923,4.063 C0.923,3.992 0.965,3.929 1.029,3.901 L9.927,-0.013 C9.973,-0.034 10.026,-0.034 10.073,-0.013 L11.608,0.662 C11.672,0.690 11.714,0.752 11.715,0.822 C11.716,0.892 11.676,0.956 11.613,0.986 L2.904,5.077 ZM2.312,10.490 C2.312,10.539 2.341,10.584 2.386,10.605 L5.927,12.269 C5.944,12.278 5.963,12.282 5.982,12.282 C6.006,12.282 6.030,12.275 6.051,12.262 C6.088,12.239 6.111,12.198 6.111,12.154 L6.111,7.482 L9.452,9.012 C9.516,9.041 9.557,9.105 9.557,9.175 L9.557,19.821 C9.557,19.882 9.526,19.939 9.474,19.972 C9.445,19.990 9.411,20.000 9.377,20.000 C9.352,20.000 9.326,19.994 9.302,19.984 L0.105,15.813 C0.041,15.784 -0.000,15.721 -0.000,15.651 L-0.000,5.005 C-0.000,4.944 0.031,4.887 0.083,4.854 C0.134,4.822 0.199,4.817 0.255,4.842 L2.312,5.786 L2.312,10.490 Z" fill="rgb(65,65,65)" fill-rule="evenodd"></path>
# </svg>
# </a>
# </div>
# <div>
# <a class="bxr-basket-indicator bxr-indicator-favor bxr-font-hover-light" data-child="bxr-favor-body" data-group="basket-group" href="javascript:void(0);" title="Избранное"> <i class="fa fa-heart"></i>
# </a>
# </div>
# <div>
# <a class="bxr-basket-indicator bxr-indicator-basket bxr-font-hover-light" data-child="bxr-basket-body" data-group="basket-group" href="javascript:void(0);" title="Моя корзина"><i aria-hidden="true" class="fa fa-shopping-basket"></i>
# </a>
# <p style="position: absolute; top: 25px; left: -20px; width: 200%;">Моя корзина</p>
# </div>
# </div>
# </div>
# <div id="bxdynamic_bxr_small_basket_end" style="display:none"></div> </div></div>
# </div>
# </div>
# </div>
# <div class="bxr-top-panel-topmenu-container">
# <div class="row">
# <div class="col-xs-12">
# <div class="hidden-sm hidden-xs">
# <div class="bxr-built-menu-container bxr-v-line_menu colored_color">
# <div class="row">
# <div class="col-sm-12"><nav>
# <ul class="bxr-flex-menu bxr-color-flat bxr-light-menu bxr-top-menu bxr-ident-items-little" data-first-catalog="N" data-stretch="Y" data-style-menu="color" data-style-menu-hover="color">
# <li class="bxr-color-flat bxr-bg-hover-dark-flat bxr-li-top-menu-parent-classic">
# <a href="/info/catalog_mob"><span class="bxr-ico-top-menu"></span>Каталог</a>
# </li>
# <li class="bxr-color-flat bxr-bg-hover-dark-flat bxr-li-top-menu-parent-classic">
# <a href="/publisher/"><span class="bxr-ico-top-menu"></span>Издательства</a>
# </li>
# <li class="bxr-color-flat bxr-bg-hover-dark-flat bxr-li-top-menu-parent-classic">
# <a href="/author/"><span class="bxr-ico-top-menu"></span>Авторы</a>
# </li>
# <li class="bxr-color-flat bxr-bg-hover-dark-flat bxr-li-top-menu-parent-classic">
# <a href="/series/"><span class="bxr-ico-top-menu"></span>Серии</a>
# </li>
# <li class="bxr-color-flat bxr-bg-hover-dark-flat bxr-li-top-menu-parent-classic">
# <a href="https://shop.relod.ru/upload/pub/Catalog_OUP_RELOD_v2.pdf"><span class="bxr-ico-top-menu"></span>Каталог OUP (ELT) и RELOD</a>
# </li>
# <li class="bxr-color-flat bxr-bg-hover-dark-flat bxr-li-top-menu-parent-classic">
# <a href="/info/how-to-main/"><span class="bxr-ico-top-menu"></span>Как найти и заказать товар</a>
# </li>
# <li class="bxr-color-flat bxr-bg-hover-dark-flat bxr-li-top-menu-parent-classic">
# <a href="/news/"><span class="bxr-ico-top-menu"></span>Новости</a>
# </li>
# <li class="bxr-color-flat bxr-bg-hover-dark-flat bxr-li-top-menu-parent-classic">
# <a href="/articles/"><span class="bxr-ico-top-menu"></span>Обзоры</a>
# </li>
# <li class="bxr-color-flat bxr-bg-hover-dark-flat bxr-li-top-menu-parent-classic">
# <a href="/info/how-to-delivery/"><span class="bxr-ico-top-menu"></span>Доставка, оплата и сроки</a>
# </li>
# <li class="bxr-color-flat bxr-bg-hover-dark-flat bxr-li-top-menu-parent-classic">
# <a href="/info/o-magazine/"><span class="bxr-ico-top-menu"></span>О нас<span class="fa fa-angle-down"></span></a>
# <div class="bxr-classic-hover-menu">
# <ul><li class="bxr-bg-hover-flat"><a class="margin-no" href="/info/o-magazine/contacts/"><span class="bxr-ico-hover-menu"></span>Контакты</a></li><li class="bxr-bg-hover-flat"><a class="margin-no" href="/info/o-magazine/reviews/index.php"><span class="bxr-ico-hover-menu"></span>Отзывы о нас</a></li><li class="bxr-bg-hover-flat"><a class="margin-no" href="/info/o-magazine/requisites/"><span class="bxr-ico-hover-menu"></span>Реквизиты</a></li><li class="bxr-bg-hover-flat"><a class="margin-no" href="/info/o-magazine/pologenie_o_person_dannih/"><span class="bxr-ico-hover-menu"></span>Обработка персональных данных</a></li><li class="bxr-bg-hover-flat"><a class="margin-no" href="/info/o-magazine/user_agreement/"><span class="bxr-ico-hover-menu"></span>Условия продажи товаров</a></li><li class="bxr-bg-hover-flat"><a class="margin-no" href="/info/o-magazine/user_agreement2/"><span class="bxr-ico-hover-menu"></span>Условия продажи услуг</a></li><li class="bxr-bg-hover-flat"><a class="margin-no" href="/info/o-magazine/user_agreement3/"><span class="bxr-ico-hover-menu"></span>Условия продажи цифровых товаров</a></li><li class="bxr-bg-hover-flat"><a class="margin-no" href="/info/o-magazine/change-and-return/"><span class="bxr-ico-hover-menu"></span>Возврат товара и денежных средств</a></li></ul></div> </li>
# <li class="bxr-color-flat bxr-bg-hover-dark-flat bxr-li-top-menu-parent-classic">
# <a href="/actions/"><span class="bxr-ico-top-menu"></span>Акции</a>
# </li>
# <li class="bxr-flex-menu-other other bxr-color-flat bxr-bg-hover-dark-flat"> </li>
# </ul><div class="clearfix"></div>
# </nav></div></div>
# </div>
# </div> </div>
# </div>
# </div>
# <div class="container-fluid container-fluid-for-menu">
# <div class="row">
# <div class="col-xl-2 col-md-3 col-sm-4 col-xs-12 bxr-element-row-middle">
# <div class="bxr-is-header" id="button_menu_container">
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <a id="bxr-top-fixed-panel-anker"></a><div id="bxr-top-fixed-panel"></div>
# </header>
# <div class="bxr-full-width bxr-work-area-container">
# <div class="container bxr-bg-container xl">
# <div class="row bxr-page-content" id="bxr-page-content">
# <div class="bxr-b20 col-xs-12">
# <div class="bxr-cloud-all bxr-cloud-padding bxr-b20">
# <div class="bxr-breadcrumb" itemscope="" itemtype="http://schema.org/BreadcrumbList">
# <div class="bxr-breadcrumb-item bxr-font-color" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <a class="bxr-font-color" href="/" itemprop="item" title="Главная">
# <span itemprop="name">Главная</span>
# <meta content="1" itemprop="position"/>
# </a>
# </div>
# <div class="bxr-breadcrumb-item bxr-font-color" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <i class="fa fa-angle-right"></i>
# <a class="bxr-font-color" href="/catalog-products/" itemprop="item" title="Каталог товаров">
# <span itemprop="name">Каталог товаров</span>
# <meta content="2" itemprop="position"/>
# </a>
# </div>
# <div class="bxr-breadcrumb-item bxr-font-color" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <i class="fa fa-angle-right"></i>
# <a class="bxr-font-color" href="/catalog-products/4577/" itemprop="item" title="Художественная литература">
# <span itemprop="name">Художественная литература</span>
# <meta content="3" itemprop="position"/>
# </a>
# </div>
# <div class="bxr-breadcrumb-item" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <i class="fa fa-angle-right"></i>
# <span title="Eleanor Oliphant is Completely Fine: Debut Bestseller and Costa First Novel Book Award winner 2017">
# <span itemprop="name">Eleanor Oliphant is Completely Fine: Debut Bestseller and Costa First Novel Book Award winner 2017</span>
# <meta content="4" itemprop="position"/>
# </span>
# </div><div style="clear:both"></div></div></div> <div class="row">
# <div class="col-xl-2 col-lg-2 col-md-12 col-sm-12 col-xs-12 hidden-md hidden-sm hidden-xs">
# <div class="bx-sidebar-block">
# <div class="bxr-show-left-menu">
# <div class="hidden-sm hidden-xs bxr-left-column-js bxr-b20 bxr-cloud-all bxr-cloud-all-br1-not bxr-cloud-all-br2-not">
# <span class="bxhtmled-surrogate-inner">
# <span class="bxhtmled-right-side-item-icon"></span>
# <span class="bxhtmled-comp-lable unselectable" spellcheck="false"></span>
# </span>
# <p class="catalog_title">Каталог товаров</p>
# <nav>
# <ul class="line-top bxr-left-menu-hover hidden-sm hidden-xs">
# <li class="top-element-js bxr-bg-hover-flat">
# <a class="" href="/catalog-products/1955/">
# <span class="bxr-ico-left-hover-menu"></span>
# <div class="img"><img alt="SALE (Распродажа)" src="//opt-1458870.ssl.1c-bitrix-cdn.ru/upload/uf/cd2/sale logo.png?15853155007123" title="SALE (Распродажа)"/></div>
# <span class="fa fa-angle-right"></span> </a>
# <div class="col-w-lg-9 col-w-md-9 bxr-list-hover-menu" data-bimg="left" data-bimgsrc="" data-lg="1" data-md="1" data-sm="1" data-xs="1">
# <div class="bxr-element-hover-menu">
# <div class="bxr-element-content">
# <div class="bxr-element-name bxr-children-color-hover">
# <a href="/catalog-products/1968/">
#                                         Sale (Распродажа) Литература для детей и подростков (английский язык)                                    </a>
# </div>
# </div>
# <div class="bxr-clear"></div>
# </div>
# <div class="bxr-element-hover-menu">
# <div class="bxr-element-content">
# <div class="bxr-element-name bxr-children-color-hover">
# <a href="/catalog-products/1963/">
#                                         Sale (Распродажа) Fiction Неадаптированная художественная литература (английский язык)                                    </a>
# </div>
# </div>
# <div class="bxr-clear"></div>
# </div>
# <div class="bxr-element-hover-menu">
# <div class="bxr-element-content">
# <div class="bxr-element-name bxr-children-color-hover">
# <a href="/catalog-products/1973/">
#                                         Sale (Распродажа) Нон-фикшн, познавательная литература, альбомы (английский язык)                                    </a>
# </div>
# </div>
# <div class="bxr-clear"></div>
# </div>
# <div class="bxr-element-hover-menu">
# <div class="bxr-element-content">
# <div class="bxr-element-name bxr-children-color-hover">
# <a href="/catalog-products/1974/">
#                                         Sale (Распродажа) Учебные курсы по английскому языку                                    </a>
# </div>
# <div class="bxr-element-items">
# <span class="bxr-children-color-hover">
# <a href="/catalog-products/7829/">
#                             Sale (Распродажа) Учебные курсы для дошкольников по английскому языку                                                    </a>
# </span>
# <span class="bxr-children-color-hover">
# <a href="/catalog-products/1975/">
#                             Sale (Распродажа) Учебные курсы для начальной школы по английскому языку                                                    </a>
# </span>
# <span class="bxr-children-color-hover">
# <a href="/catalog-products/1976/">
#                             Sale (Распродажа) Учебные курсы для основной и средней школы по английскому языку                                                    </a>
# </span>
# <span class="bxr-children-color-hover">
# <a href="/catalog-products/1977/">
#                             Sale (Распродажа) Учебные курсы для студентов и взрослых по английскому языку                                                    </a>
# </span>
# </div>
# </div>
# <div class="bxr-clear"></div>
# </div>
# <div class="bxr-element-hover-menu">
# <div class="bxr-element-content">
# <div class="bxr-element-name bxr-children-color-hover">
# <a href="/catalog-products/1972/">
#                                         Sale (Распродажа) Словари и справочная литература (английский язык)                                    </a>
# </div>
# </div>
# <div class="bxr-clear"></div>
# </div>
# <div class="bxr-element-hover-menu">
# <div class="bxr-element-content">
# <div class="bxr-element-name bxr-children-color-hover">
# <a href="/catalog-products/1967/">
#                                         Sale (Распродажа) Грамматика и лексика (английский язык)                                    </a>
# </div>
# </div>
# <div class="bxr-clear"></div>
# </div>
# <div class="bxr-element-hover-menu">
# <div class="bxr-element-content">
# <div class="bxr-element-name bxr-children-color-hover">
# <a href="/catalog-products/1964/">
#                                         Sale (Распродажа) Книги по адаптированному чтению (английский язык)                                    </a>
# </div>
# </div>
# <div class="bxr-clear"></div>
# </div>
# <div class="bxr-element-hover-menu">
# <div class="bxr-element-content">
# <div class="bxr-element-name bxr-children-color-hover">
# <a href="/catalog-products/1979/">
#                                         Sale (Распродажа) Языковые навыки (английский язык)                                    </a>
# </div>
# </div>
# <div class="bxr-clear"></div>
# </div>
# <div class="bxr-element-hover-menu">
# <div class="bxr-element-content">
# <div class="bxr-element-name bxr-children-color-hover">
# <a href="/catalog-products/7827/">
#                                         Sale (Распродажа) Английский для академических целей                                    </a>
# </div>
# </div>
# <div class="bxr-clear"></div>
# </div>
# <div class="bxr-element-hover-menu">
# <div class="bxr-element-content">
# <div class="bxr-element-name bxr-children-color-hover">
# <a href="/catalog-products/1965/">
#                                         Sale (Распродажа) Английский для бизнеса и профессий                                    </a>
# </div>
# </div>
# <div class="bxr-clear"></div>
# </div>
# <div class="bxr-element-hover-menu">
# <div class="bxr-element-content">
# <div class="bxr-element-name bxr-children-color-hover">
# <a href="/catalog-products/7828/">
#                                         Sale (Распродажа) Пособия по страноведению на английском языке                                    </a>
# </div>
# </div>
# <div class="bxr-clear"></div>
# </div>
# <div class="bxr-element-hover-menu">
# <div class="bxr-element-content">
# <div class="bxr-element-name bxr-children-color-hover">
# <a href="/catalog-products/1978/">
#                                         Sale (Распродажа) Подготовка к экзаменам (английский язык)                                    </a>
# </div>
# </div>
# <div class="bxr-clear"></div>
# </div>
# <div class="bxr-element-hover-menu">
# <div class="bxr-element-content">
# <div class="bxr-element-name bxr-children-color-hover">
# <a href="/catalog-products/1969/">
#                                         Sale (Распродажа) Методическая литература для преподавателей и лингвистика (английский язык)                                    </a>
# </div>
# </div>
# <div class="bxr-clear"></div>
# </div>
# <div class="bxr-element-hover-menu">
# <div class="bxr-element-content">
# <div class="bxr-element-name bxr-children-color-hover">
# <a href="/catalog-products/7826/">
#                                         Sale (Распродажа) Образовательная литература и учебные пособия для школьных международных программ (английский язык)                                    </a>
# </div>
# </div>
# <div class="bxr-clear"></div>
# </div>
# <div class="bxr-element-hover-menu">
# <div class="bxr-element-content">
# <div class="bxr-element-name bxr-children-color-hover">
# <a href="/catalog-products/1966/">
#                                         Sale (Распродажа) Гиды и путеводители для путешествий (английский язык)                                    </a>
# </div>
# </div>
# <div class="bxr-clear"></div>
# </div>
# <div class="bxr-element-hover-menu">
# <div class="bxr-element-content">
# <div class="bxr-element-name bxr-children-color-hover">
# <a href="/catalog-products/1970/">
#                                         Sale (Распродажа) Научная, академическая и специализированная литература (английский язык)                                    </a>
# </div>
# </div>
# <div class="bxr-clear"></div>
# </div>
# <div class="bxr-element-hover-menu">
# <div class="bxr-element-content">
# <div class="bxr-element-name bxr-children-color-hover">
# <a href="/catalog-products/1983/">
#                                         Soldes (Распродажа) Учебные курсы по французскому языку                                    </a>
# </div>
# <div class="bxr-element-items">
# <span class="bxr-children-color-hover">
# <a href="/catalog-products/1984/">
#                             Soldes (Распродажа) Учебные курсы для дошкольников и начальной школы (французский язык)                                                    </a>
# </span>
# <span class="bxr-children-color-hover">
# <a href="/catalog-products/1985/">
#                             Soldes (Распродажа) Учебные курсы для основной и средней школы (французский язык)                                                    </a>
# </span>
# <span class="bxr-children-color-hover">
# <a href="/catalog-products/1986/">
#                             Soldes (Распродажа) Учебные курсы для студентов и взрослых (французский язык)                                                    </a>
# </span>
# </div>
# </div>
# <div class="bxr-clear"></div>
# </div>
# <div class="bxr-element-hover-menu">
# <div class="bxr-element-content">
# <div class="bxr-element-name bxr-children-color-hover">
# <a href="/catalog-products/1980/">
#                                         Soldes (Распродажа) Пособия по грамматике, лексике, языковым навыкам, cловарям и методической литературе (французский язык)                                    </a>
# </div>
# </div>
# <div class="bxr-clear"></div>
# </div>
# <div class="bxr-element-hover-menu">
# <div class="bxr-element-content">
# <div class="bxr-element-name bxr-children-color-hover">
# <a href="/catalog-products/1987/">
#                                         Soldes (Распродажа) Французский для бизнеса и профессий                                    </a>
# </div>
# </div>
# <div class="bxr-clear"></div>
# </div>
# <div class="bxr-element-hover-menu">
# <div class="bxr-element-content">
# <div class="bxr-element-name bxr-children-color-hover">
# <a href="/catalog-products/1988/">
#                                         Soldes (Распродажа) Подготовка к экзаменам (французский язык)                                    </a>
# </div>
# </div>
# <div class="bxr-clear"></div>
# </div>
# <div class="bxr-element-hover-menu">
# <div class="bxr-element-content">
# <div class="bxr-element-name bxr-children-color-hover">
# <a href="/catalog-products/1981/">
#                                         Soldes (Распродажа) Книги для чтения (французский язык)                                    </a>
# </div>
# <div class="bxr-element-items">
# <span class="bxr-children-color-hover">
# <a href="/catalog-products/1982/">
#                             Soldes (Распродажа) Адаптированные книги для чтения (французский язык)                                                    </a>
# </span>
# </div>
# </div>
# <div class="bxr-clear"></div>
# </div>
# <div class="bxr-element-hover-menu">
# <div class="bxr-element-content">
# <div class="bxr-element-name bxr-children-color-hover">
# <a href="/catalog-products/1957/">
#                                         Saldos (Распродажа) Учебная литература по испанскому языку                                    </a>
# </div>
# <div class="bxr-element-items">
# <span class="bxr-children-color-hover">
# <a href="/catalog-products/1958/">
#                             Saldos (Распродажа) Адаптированные книги для чтения (испанский язык)                                                    </a>
# </span>
# <span class="bxr-children-color-hover">
# <a href="/catalog-products/1959/">
#                             Saldos (Распродажа) Грамматика, лексика, языковые навыки (испанский язык)                                                    </a>
# </span>
# <span class="bxr-children-color-hover">
# <a href="/catalog-products/1960/">
#                             Saldos (Распродажа) Испанский для специальных целей, бизнеса и профессий                                                    </a>
# </span>
# <span class="bxr-children-color-hover">
# <a href="/catalog-products/1961/">
#                             Saldos (Распродажа) Словари (испанский язык)                                                    </a>
# </span>
# <span class="bxr-children-color-hover">
# <a href="/catalog-products/1962/">
#                             Saldos (Распродажа) Учебные курсы по испанскому языку                                                    </a>
# </span>
# </div>
# </div>
# <div class="bxr-clear"></div>
# </div>
# <div class="bxr-element-hover-menu">
# <div class="bxr-element-content">
# <div class="bxr-element-name bxr-children-color-hover">
# <a href="/catalog-products/1956/">
#                                         Saldi (Распродажа) Учебная литература по итальянскому языку                                    </a>
# </div>
# </div>
# <div class="bxr-clear"></div>
# </div>
# <div class="bxr-element-hover-menu">
# <div class="bxr-element-content">
# <div class="bxr-element-name bxr-children-color-hover">
# <a href="/catalog-products/1989/">
#                                         Verkauf (Распродажа) Учебная литература по немецкому языку                                    </a>
# </div>
# </div>
# <div class="bxr-clear"></div>
# </div>
# <div class="bxr-element-hover-menu">
# <div class="bxr-element-content">
# <div class="bxr-element-name bxr-children-color-hover">
# <a href="/catalog-products/1971/">
#                                         Sale Распродажа (другие языки)                                    </a>
# </div>
# </div>
# <div class="bxr-clear"></div>
# </div>
# <div class="bxr-element-hover-menu">
# <div class="bxr-element-content">
# <div class="bxr-element-name bxr-children-color-hover">
# <a href="/catalog-products/7975/">
#                                         Sale (Распродажа) Книги по адаптированному чтению (по всем иностранным языкам)                                    </a>
# </div>
# </div>
# <div class="bxr-clear"></div>
# </div>
# <div class="bxr-element-hover-menu">
# <div class="bxr-element-content">
# <div class="bxr-element-name bxr-children-color-hover">
# <a href="/catalog-products/7741/">
#                                         Sale (Распродажа) Обучающие игры для детей (английский язык)                                    </a>
# </div>
# </div>
# <div class="bxr-clear"></div>
# </div>
# </div> </li>
# <li class="top-element-js bxr-bg-hover-flat">
# <a class="" href="/catalog-products/7748/">
# <span class="bxr-ico-left-hover-menu"></span>
#
#                                                             Журнал "Иностранные языки в школе"
#                             <span class="fa fa-angle-right"></span> </a>
# <div class="col-w-lg-9 col-w-md-9 bxr-list-hover-menu" data-bimg="left" data-bimgsrc="" data-lg="1" data-md="1" data-sm="1" data-xs="1">
# <div class="bxr-element-hover-menu">
# <div class="bxr-element-content">
# <div class="bxr-element-name bxr-children-color-hover">
# <a href="/catalog-products/7838/">
#                                         Журнал "Иностранные языки в школе" 2020                                    </a>
# </div>
# </div>
# <div class="bxr-clear"></div>
# </div>
# <div class="bxr-element-hover-menu">
# <div class="bxr-element-content">
# <div class="bxr-element-name bxr-children-color-hover">
# <a href="/catalog-products/7839/">
# ...
# 					src += '&' + Math.floor(Math.random() * 10000);
# 					e.target.src = src;
# 				}
# 			});
# 		</script>
# <script type="text/javascript">var _ba = _ba || []; _ba.push(["aid", "000c12162c926149649728e2287b9c31"]); _ba.push(["host", "shop.relod.ru"]); _ba.push(["ad[ct][item]", "..."]);_ba.push(["ad[ct][user_id]", function(){return BX.message("USER_ID") ? BX.message("USER_ID") : 0;}]);_ba.push(["ad[ct][recommendation]", function() {var rcmId = "";var cookieValue = BX.getCookie("BITRIX_SM_RCM_PRODUCT_LOG");var productId = 197389;var cItems = [];var cItem;if (cookieValue){cItems = cookieValue.split(".");}var i = cItems.length;while (i--){cItem = cItems[i].split("-");if (cItem[0] == productId){rcmId = cItem[1];break;}}return rcmId;}]);_ba.push(["ad[ct][v]", "2"]);(function() {var ba = document.createElement("script"); ba.type = "text/javascript"; ba.async = true;ba.src = (document.location.protocol == "https:" ? "https://" : "http://") + "bitrix.info/ba.js";var s = document.getElementsByTagName("script")[0];s.parentNode.insertBefore(ba, s);})();</script>
# <script>window.BXReady.coreData = {'lg_breakpoint':'1919','md_breakpoint':'1199','sm_breakpoint':'991','xs_breakpoint':'761','left_column':'Y','left_menu':'Y','isCatalog':'Y','right_column':'N','xl_mode':true,'xl_class':'xl'}</script><script>
# 	BX.ready(function(){
# 		new JCTitleSearch({
# 			'AJAX_PAGE' : '/catalog-products/eleanor_oliphant_is_completely_fine_debut_bestseller_and_costa_first_novel_book_award_winner_2017/',
# 			'CONTAINER_ID': 'title-search-in-top',
# 			'INPUT_ID': 'title-search-input-in-top',
# 			'MIN_QUERY_LEN': 2
# 		});
# 	});
# </script>
# <script>
# 	BX.ready(function(){
# 		new JCTitleSearch({
# 			'AJAX_PAGE' : '/catalog-products/eleanor_oliphant_is_completely_fine_debut_bestseller_and_costa_first_novel_book_award_winner_2017/',
# 			'CONTAINER_ID': 'title-search-in-top2',
# 			'INPUT_ID': 'title-search-input-in-top2',
# 			'MIN_QUERY_LEN': 2
# 		});
# 	});
# </script>
# <script>
#     $(document).ready(function() {
#         var obTopMenu = new JCTopMenu({});
#     });
# </script><script>
#     $(document).ready(function() {
#         $('.bxr-show-left-menu .bxr-left-column-js.isHidden').prependTo( '#button_menu_container' );
#         $('#basket_container .login-line').attr("href", $('#login-line + a').attr("href")).attr("onclick", $('#login-line + a').attr("onclick"));
#     });
# </script>
# <script>
#                 var panelFixed = new JCTopFixedPanelAjax({
#                         'mWidth': 900,
#                         'siteId': 's1',
#                         'templateID': '/local/templates/market2_v1',
#                         'ajaxUrl': '/local/templates/market2_v1/components/bxready.market2/panel.top.fixed.ajax/.default/ajax.php',
#                         'parameters': '.3c9db15d0f9ef4959ce36df16dd9a06296c8977cb2973638d090aeb496b8d705',
#                         'bxmarket': '.f3851d638c71a9b0f1c6fff32f5ba20dd85b7e0f19eaa03d3376f61df283e3a3',
#                 });
#             </script>
# <script>
#     $(document).ready(function() {
#         var obLeftMenu = new JCLeftMenu({
#
#         });
#     });
# </script><script>
#         function fancyReinit() {
#             $("[data-fancybox]").fancybox({
#                 slideShow: false,
#                 fullScreen: false,
#                 onComplete: function() {
#                     $('.fancybox-thumbs').scrollbar();
#                     $('.scroll-bar').addClass('bxr-color');
#                 },
#                 thumbs : {
#                     showOnStart: true,
#                 },
#             });
#         };
#
#         function zoomReInit() {
#             $('.bxr-zoom-img').loupe({loupe:'bxr-loupe'});
#         };
#
#         $('#'+'bx_117848907_197389_slider_cont').on('afterChange', function(event, slick, currentSlide, nextSlide){
#             data = $('#bx_117848907_197389_slider_cont').find('.slick-active').data('slick-index');
#             $($('#bx_117848907_197389_slider_nav_cont'+' .slick-track').children('.slick-slide')).removeClass("bxr-border-color").addClass("bxr-def-border");
#             $($('#bx_117848907_197389_slider_nav_cont'+' .slick-track').children('.slick-slide[data-slick-index='+data+']')).removeClass("bxr-def-border").addClass("bxr-border-color");
#         });
#
#         var obbx_117848907_197389_slider_cont = $('#bx_117848907_197389_slider_cont').slick({
#             slidesToShow: 1,
#             slidesToScroll: 1,
#             speed: 300,
#             arrows: true,
#             prevArrow: '<button type="button" class="bxr-color-button slick-prev"></button>',
#             nextArrow: '<button type="button" class="bxr-color-button slick-next"></button>',
#             fade: true,
#             dots: false,
#             infinite: true,
#             cssEase: 'linear',
#             asNavFor: '#bx_117848907_197389_slider_nav_cont',
#             slide: 'a'
#         });
#
#         $('#bx_117848907_197389_slider_nav_cont').on('afterChange', function(event, slick, currentSlide, nextSlide){
#             $($('#bx_117848907_197389_slider_nav_cont'+' .slick-nav')).removeClass("bxr-border-color").addClass("bxr-def-border");
#             $('#bx_117848907_197389_slider_nav_cont'+' .slick-nav.slick-current').removeClass("bxr-def-border").addClass("bxr-border-color");
#         });
#
#         var obbx_117848907_197389_slider_nav_cont = $('#bx_117848907_197389_slider_nav_cont').slick({
#             slidesToShow: 4,
#             slidesToScroll: 1,
#             speed: 300,
#             arrows: true,
#             prevArrow: '<button type="button" class="bxr-color-button slick-prev"></button>',
#             nextArrow: '<button type="button" class="bxr-color-button slick-next"></button>',
#             dots: false,
#             infinite: true,
#             centerMode: false,
#             cssEase: 'linear',
#             asNavFor: '#bx_117848907_197389_slider_cont',
#             focusOnSelect: false,
#             slide: 'div'
#         });
#
#
#         $('#bx_117848907_197389_slider_nav_cont'+' .slick-slide').on('click', function(e){
#             sCnt = $('#bx_117848907_197389_slider_nav_cont'+' .slick-nav:not(.slick-cloned)').length - 1;
#             c = $('#bx_117848907_197389_slider_nav_cont'+' .slick-nav:not(.slick-cloned)[data-item='+$(this).data('item')+'][data-slick-index='+$(this).data('slick-index')+']').index();
#             clone = $('#bx_117848907_197389_slider_nav_cont'+' .slick-nav.slick-cloned').length / 2;
#             index = (c>0) ? c - clone : 0;
#             gSlide = (index > sCnt) ? sCnt : index;
#
#             $($('#bx_117848907_197389_slider_nav_cont'+' .slick-nav')).removeClass("bxr-border-color").addClass("bxr-def-border");
#             $(this).removeClass("bxr-def-border").addClass("bxr-border-color");
#
#             setTimeout(function() {$('#bx_117848907_197389_slider_nav_cont').slick('slickGoTo', gSlide)}, 300);
#             setTimeout(function() {$('#bx_117848907_197389_slider_cont').slick('slickGoTo', gSlide)}, 300);
#         });
#
#         $(document).ready(function() {
#             $('#bx_117848907_197389_slider_nav_cont').children(".slick-prev").css("display", "none");
#             $('#bx_117848907_197389_slider_nav_cont').children(".slick-next").css("display", "none");
#             $('#bx_117848907_197389_slider_cont').children(".slick-prev").css("display", "none");
#             $('#bx_117848907_197389_slider_cont').children(".slick-next").css("display", "none");
#             $('#bx_117848907_197389_slider_wrap').show();
#             $('#bx_117848907_197389_slider_nav_cont').slick('slickFilter','[data-main="default"]');
#             $('#bx_117848907_197389_slider_cont').slick('slickFilter','[data-main="default"]');
#             $($('#bx_117848907_197389_slider_nav_cont'+' .slick-nav:not(.slick-cloned)')[0]).addClass("bxr-border-color");
#             $($('#bx_117848907_197389_slider_nav_cont'+' .slick-nav:not(.slick-cloned)')[0]).trigger('click');
#             fancyReinit();
#
#
#             var lazyLoadInstance = new LazyLoad({
#                 elements_selector: ".lazy"
#             });
#         });
#
#         $(window).on("load", function() {
#             setSlideSizes();
#         });
#
#         $(document).on("mouseover", '#bx_117848907_197389_slider_nav_cont', function() {
#             hideArrows(this, "block");
#         });
#
#         $(document).on("mouseover", '#bx_117848907_197389_slider_cont', function() {
#             hideArrows(this, "block");
#         });
#
#         $(document).on("mouseout", '#bx_117848907_197389_slider_nav_cont', function() {
#             hideArrows(this, "none");
#         });
#
#         $(document).on("mouseout", '#bx_117848907_197389_slider_cont', function() {
#             hideArrows(this, "none");
#         });
#
#         $(window).resize(function() {
#             setSlideSizes();
#         });
#
#         function hideArrows(elem, display) {
#             $(elem).children(".slick-prev").css("display", display);
#             $(elem).children(".slick-next").css("display", display);
#         }
#
#         function setSlideSizes() {
#             border = 4;
#             width = $('#bx_117848907_197389_slider_nav_cont'+' .slick-list .slick-track .slick-slide').width();
#             height = width + border;
#             imgSize = width - 10;
#             $('#bx_117848907_197389_slider_nav_cont'+' .slick-track .slick-slide').height(height);
#             $('#bx_117848907_197389_slider_nav_cont'+' .slick-track .slick-slide .slide-wrap').css({'width': height, 'height': height, 'line-height': height+'px'})
#         }
#
#             </script>
# <script type="text/javascript">
# BX.ready(function(){
# 	window.bx_vo_2_197389_sBq3II = new JCIblockVoteStars({'progressId':'bx_vo_2_197389_sBq3II_progr','ratingId':'bx_vo_2_197389_sBq3II_rating','starsId':'bx_vo_2_197389_sBq3II_stars','ajaxUrl':'/bitrix/components/bitrix/iblock.vote/component.php','voteId':'197389'});
#
# 	window.bx_vo_2_197389_sBq3II.ajaxParams = {'SESSION_PARAMS':'3e599503911a9d8012bd28ea238cfd05','PAGE_PARAMS':{'ELEMENT_ID':'197389'},'sessid':'919bbe38f7bff4fcaaeef817f16a1b23','AJAX_CALL':'Y'};
# 	window.bx_vo_2_197389_sBq3II.setValue("100");
# 	window.bx_vo_2_197389_sBq3II.setVotes("1");
# });
# </script><script type="text/javascript">
# BX.ready(
# 	BX.defer(function(){
# 		if (!!window.bx_vo_2_197389_sBq3II)
# 		{
# 			window.bx_vo_2_197389_sBq3II.bindEvents();
# 		}
# 	})
# );
# </script>
# <script>
#         BXReady.Market.basketValues[197389] = {
#             ID: '197389',
#             OFFER_ID: '',
#             NAME: 'Eleanor Oliphant is Completely Fine: Debut Bestseller and Costa First Novel Book Award winner 2017',
#             LINK: '/catalog-products/eleanor_oliphant_is_completely_fine_debut_bestseller_and_costa_first_novel_book_award_winner_2017/',
#             IMG: '/upload/iblock/c8d/c8d3289127d42d2e939046f0d7e85a36.jpg',
#             MSG: 'Я хочу приобрести товар Eleanor Oliphant is Completely Fine: Debut Bestseller and Costa First Novel Book Award winner 2017',
#             HAS_PRICE: 'Y',
#             CATALOG_QUANTITY: '1',
#             CATALOG_CAN_BUY_ZERO: 'Y',
#             CATALOG_SUBSCRIBE: 'N',
#             QTY_MAX: '0',
#             RATIO: '1',
#             START_QTY: '1'
#         };
#     </script>
# <script>
#     $(document).ready(function() {
#         var maxLength = parseInt($('.bxr-detail-tabs').css('width'));
#         var curLength = 0; var tabCnt = 0;
#         for (i=$('.bxr-detail-tab-div').length-1;i>-1;i--) {
#             curLength += (parseInt($($('.bxr-detail-tab-div')[i]).css('width')));
#             tabCnt++;
#             if (curLength >= maxLength) break;
#         }
#         prevBtn = '<button type="button" class="slick-prev slick-arrow slick-tabs-arrow slick-tabs-arrow-prev  bxr-color bxr-color-dark-hover fa fa-chevron-left"></button>';
#         nextBtn = '<button type="button" class="slick-prev slick-arrow slick-tabs-arrow slick-tabs-arrow-next  bxr-color bxr-color-dark-hover fa fa-chevron-right"></button>';
#         $('.bxr-detail-tabs').slick({
#                 dots: false,
#                 infinite: false,
#                 speed: 300,
#                 slidesToShow: tabCnt,
#                 centerMode: false,
#                 variableWidth: true,
#                 prevArrow: prevBtn,
#                 nextArrow: nextBtn,
# //                slide: 'li'
#         });
#     });
#     </script>
# <script>
# 	    var digitalEnable = 'Y';
# </script>
# <script>
# 		$(document).ready(function(){
# 				if (typeof(BXReady.Market) === 'object') {
# 					if (typeof(BXReady.Market.exportData !== 'object')){
# 						BXReady.Market.exportData = [];
# 					}
# 					BXReady.Market.exportData.push('eyJjb250ZW50X3R5cGUiOiJjYXRhbG9nX2VsZW1lbnQiLCJjb250ZW50X2l0ZW0iOjE5NzM4OSwiY29udGVudF9pYmxvY2siOiIyIn0=');
# 				}
# 		})
# 		</script><script>
# 		BX.ready(function()
# 		{
# 			BX.bind(BX("bx_subscribe_btn_dNLuFZ"), 'click', function() {
# 				setTimeout(mailSender, 250);
# 				return false;
# 			});
# 		});
#
# 		function mailSender()
# 		{
# 			setTimeout(function() {
# 				var btn = BX("bx_subscribe_btn_dNLuFZ");
# 				if(btn)
# 				{
# 					var btn_span = btn.querySelector("span");
# 					var btn_subscribe_width = btn_span.style.width;
# 					BX.addClass(btn, "send");
# 					btn_span.outterHTML = "<span><i class='fa fa-check'></i> ГОТОВО</span>";
# 					if(btn_subscribe_width)
# 						btn.querySelector("span").style["min-width"] = btn_subscribe_width+"px";
# 				}
# 			}, 400);
# 		}
# 	</script>
# <script>
#         $(document).ready(function(){
#             var fastView_ = new JCCatalogFastView({
#                 ajaxUrl: '/local/templates/market2_v1/components/bxready.market2/catalog.fast.view/.default/ajax.php',
#                 postData: {
#                     siteId : 's1',
#                     template : '.default.5d0957cc15814bbeac66603392e0601d1174ec5350261ffd27a6b33304a7ddc6',
#                     parameters : '....1b0d800ab3e6859e2de4e3c6911873e7b4a29988847c23be3e7f27a7d6d571fb'
#                 }
#             });
#         });
#     </script><script>
#     $(document).ready(function(){
#         window.BXReady.Market.buttonUp.init(
#             "150",
#             "150",
#             "10");
#     });
# </script><script>
#     BX.OrderHistory.CurrentStatusesListPopup.init({'url':'/local/components/o2k/order.history/templates/current_statuses_list_popup/ajax.php','container':'#order_status_current_statuses_list_popup','componentParams':{'ACTIVE_DATE_FORMAT':'d.m.Y G:i','CACHE_GROUPS':'Y','CACHE_TIME':'3600','CACHE_TYPE':'A','ORDER_DETAIL_URL':'/personal/orders/#ORDER_NUMBER#','~ACTIVE_DATE_FORMAT':'d.m.Y G:i','~CACHE_GROUPS':'Y','~CACHE_TIME':'3600','~CACHE_TYPE':'A','~ORDER_DETAIL_URL':'/personal/orders/#ORDER_NUMBER#'}});
# </script><script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-52861309-1"></script>
# <script>
#     window.dataLayer = window.dataLayer || [];
#     function gtag(){dataLayer.push(arguments);}
#     gtag('js', new Date());
#
#     gtag('config', 'UA-52861309-1');
# </script>
# <script>
#     (function(w,d,u){
#         var s=d.createElement('script');s.async=true;s.src=u+'?'+(Date.now()/60000|0);
#         var h=d.getElementsByTagName('script')[0];h.parentNode.insertBefore(s,h);
#     })(window,document,'https://cdn.bitrix24.ru/b848679/crm/site_button/loader_3_dpusyj.js');
# </script><script>
#         if(digitalEnable == undefined){
#                         var digitalEnable = 'Y';
#         }
#     </script>
# </body>
# </html>
# <!--38ff45408b6c584645cc9cdb8337ea39-->

# %%
test_html.find(re.compile("ptvSettings"))

# %%
import time 
import pandas as pd

def get_page_html(url, n_attempts=5, t_sleep=1):
    for i in range(n_attempts):
        r = requests.get(url)
        if r.ok:
            return BeautifulSoup(r.content, 'lxml')
        time.sleep(t_sleep)

def get_data(url):
    page_data = {}
#     page_data["url"] = f'{relod_url}{url}'
#     book_soup = get_page_html(page_data["url"])
#     if book_soup is None:
#         return
    book_soup = test_html
    
    # getting name of book
    name = book_soup.find('h1', {"itemprop": "name"})
    if name is not None:
        page_data['Название'] = name.text.strip()
    
    # getting urls of images
    main_picture = book_soup.find('div', {"class": "bxr-element-slider-main"})
    if main_picture is not None:
        image_tags = main_picture.find_all('img', {"itemprop": "image"})
        if image_tags is not None:
            illustrations_urls = list({image_tag['data-src'] 
                                             for image_tag in image_tags 
                                             if 'data-src' in image_tag.attrs is not None})
            if len(illustrations_urls) != 0:
                page_data['Иллюстрации'] = illustrations_urls
    
    # getting markers of book
    marker_table = book_soup.find('div', {"class": "bxr-ribbon-marker-vertical"})
    if marker_table is not None:
        marker_tags = marker_table.find_all('span')
        if marker_tags is not None:
            markers = [marker_tag.text.strip() for marker_tag in marker_tags
                      if len(marker_tag.text.strip()) != 0]
            page_data['Метки'] = markers
    
    # getting main information about book
    main_table = book_soup.find('div', {"class": ["bxr-preview-detail-col"]})
    if main_table is not None:
        # rating
        rating_count, rating_value = 0, 0
        rating_table = main_table.find('div', {"class": "bxr-rating-detail"})
        if rating_table is not None:
            rating_value_tag = rating_table.find('meta', {"itemprop": "ratingValue"})
            rating_count_tag = rating_table.find('meta', {"itemprop": "ratingCount"})
            if rating_value_tag is not None and "content" in rating_value_tag.attrs:
                content = rating_value_tag["content"]
                if content is not None and content.isdigit():
                    rating_value = float(content)
            
            if rating_count_tag is not None:
                content = rating_count_tag["content"]
                if content is not None and content.isdigit():
                    rating_count = int(content)
        
        page_data['Оценка'] = rating_value
        page_data['Число голосов'] = rating_count
        
        # geting table information
        table = main_table.find('table', {"class": "bxr-props-table"})
        # Here we believe that all tables on relod.ru are correct =)
        if table is not None:
            name_tags = table.find_all(itemprop="name")
            value_tags = table.find_all(itemprop="value")
            d_table = {name_tag.text.strip(): value_tag.text.strip()
                      for name_tag, value_tag in zip(name_tags, value_tags)}
            page_data.update(d_table)
        
    # getting offer information
    offer_table = book_soup.find('div', {"id": "bxr-right-col-detail"})
    if offer_table is not None:
        # availability
        avail_tag = offer_table.find('div', {"itemprop": "availability"})
        avail = "Нет информации"
        if avail_tag is not None:
            avail = avail_tag.text.strip()
        page_data["Наличие"] = avail
        
        # price
        price_tag = offer_table.find(itemprop="price")
        if price_tag is not None and "content" in price_tag.attrs:
                if price_tag["content"].isdigit():
                    page_data["Цена"] = float(price_tag["content"])
        # discount price
            
        
    return page_data
    

get_data('1')
# Out:
# {'Название': 'Eleanor Oliphant is Completely Fine: Debut Bestseller and Costa First Novel Book Award winner 2017',
#  'Иллюстрации': ['//opt-1458870.ssl.1c-bitrix-cdn.ru/upload/iblock/4af/9780008172145.jpg?1550839434308919',
#   '//opt-1458870.ssl.1c-bitrix-cdn.ru/upload/iblock/6af/9780008172145_0.jpg?155083943443272'],
#  'Метки': ['Хит'],
#  'Оценка': 5.0,
#  'Число голосов': 1,
#  'ISBN': '9780008172145',
#  'Издатель': 'Harper Collins',
#  'Автор': 'Honeyman Gail',
#  'Язык': 'English',
#  'Возрастные ограничения': '16+',
#  'Рекомендованный возраст': '16+',
#  'Формат': 'Paperback',
#  'Страницы': '400',
#  'Год издания': '2018',
#  'Страна происхождения': 'Соединенное Королевство',
#  'Рейтинг': '3.3',
#  'Вес (грамм)': '250',
#  'Наличие': 'В наличии',
#  'Цена': 762.0}

# %%
int('ads')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-226-42cf3caddd58> in <module>
# ----> 1 int('ads')
#
# ValueError: invalid literal for int() with base 10: 'ads'
